# %%
import time

# %%
def SearchOverGenomeWithImprovedSort(genome, pattern, stepSize):
    indexes = []
    totalTime = 0
    patternLength = len(pattern)
    
    subString = genome[:stepSize] + "$"
    
    startTime = time.time()
    tempIndexes = SearchViaImprovedSort(subString, pattern)
    endTime = time.time()
    totalTime += endTime - startTime
    
    indexes.append(list(filter(lambda x:x>-1, tempIndexes)))
    
    for i in range(1, (len(genome)//stepSize)+1):
        subString = genome[(i*stepSize)-patternLength+1:(i*stepSize)+patternLength-1] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaImprovedSort(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+(i*stepSize)-patternLength+1,filter(lambda x:x>-1, tempIndexes))))
        
        subString = genome[i*stepSize:i*stepSize+stepSize] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaImprovedSort(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+i*stepSize,filter(lambda x:x>-1, tempIndexes))))
        
    finalIndexes = [indexes[i] for i in range(0,len(indexes)) if indexes[i] != []]
    if finalIndexes:
        return ([item for sublist in finalIndexes for item in sublist], totalTime)
    else:
        return ([-1], totalTime)

# %%
def SearchOverGenomeWithImprovedDict(genome, pattern, stepSize):
    indexes = []
    totalTime = 0
    patternLength = len(pattern)
    
    subString = genome[:stepSize] + "$"
    
    startTime = time.time()
    tempIndexes = SearchViaImprovedDict(subString, pattern)
    endTime = time.time()
    totalTime += endTime - startTime
    
    indexes.append(list(filter(lambda x:x>-1, tempIndexes)))
    
    for i in range(1, (len(genome)//stepSize)+1):
        subString = genome[(i*stepSize)-patternLength+1:(i*stepSize)+patternLength-1] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaImprovedDict(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+(i*stepSize)-patternLength+1,filter(lambda x:x>-1, tempIndexes))))
        
        subString = genome[i*stepSize:i*stepSize+stepSize] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaImprovedDict(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+i*stepSize,filter(lambda x:x>-1, tempIndexes))))
        
    finalIndexes = [indexes[i] for i in range(0,len(indexes)) if indexes[i] != []]
    if finalIndexes:
        return ([item for sublist in finalIndexes for item in sublist], totalTime)
    else:
        return ([-1], totalTime)

# %%
def SearchOverGenomeWithOldSA(genome, pattern, stepSize):
    indexes = []
    totalTime = 0
    patternLength = len(pattern)
    
    subString = genome[:stepSize] + "$"
    
    startTime = time.time()
    tempIndexes = SearchViaOldSA(subString, pattern)
    endTime = time.time()
    totalTime += endTime - startTime
    
    indexes.append(list(filter(lambda x:x>-1, tempIndexes)))
    
    for i in range(1, (len(genome)//stepSize)+1):
        subString = genome[(i*stepSize)-patternLength+1:(i*stepSize)+patternLength-1] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaOldSA(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+(i*stepSize)-patternLength+1,filter(lambda x:x>-1, tempIndexes))))
        
        subString = genome[i*stepSize:i*stepSize+stepSize] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaOldSA(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+i*stepSize,filter(lambda x:x>-1, tempIndexes))))
        
    finalIndexes = [indexes[i] for i in range(0,len(indexes)) if indexes[i] != []]
    if finalIndexes:
        return ([item for sublist in finalIndexes for item in sublist], totalTime)
    else:
        return ([-1], totalTime)

# %%
def SearchOverGenomeWithBWM(genome, pattern, stepSize):
    indexes = []
    totalTime = 0
    patternLength = len(pattern)
    
    subString = genome[:stepSize] + "$"
    
    startTime = time.time()
    tempIndexes = SearchViaBWM(subString, pattern)
    endTime = time.time()
    totalTime += endTime - startTime
    
    indexes.append(list(filter(lambda x:x>-1, tempIndexes)))
    
    for i in range(1, (len(genome)//stepSize)+1):
        subString = genome[(i*stepSize)-patternLength+1:(i*stepSize)+patternLength-1] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaBWM(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+(i*stepSize)-patternLength+1,filter(lambda x:x>-1, tempIndexes))))
        
        subString = genome[i*stepSize:i*stepSize+stepSize] + "$"
        
        startTime = time.time()
        tempIndexes = SearchViaBWM(subString, pattern)
        endTime = time.time()
        totalTime += endTime - startTime
        
        indexes.append(list(map(lambda x:x+i*stepSize,filter(lambda x:x>-1, tempIndexes))))
        
    finalIndexes = [indexes[i] for i in range(0,len(indexes)) if indexes[i] != []]
    if finalIndexes:
        return ([item for sublist in finalIndexes for item in sublist], totalTime)
    else:
        return ([-1], totalTime)
